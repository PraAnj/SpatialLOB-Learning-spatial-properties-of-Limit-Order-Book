# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
# plot validation losses
# https://stackoverflow.com/questions/41908379/keras-plot-training-validation-and-test-set-accuracy
def visualizeMetric(metric='loss'):
    plt.plot(df[metric])
    plt.plot(df['val_' + metric])
    plt.ylabel(metric)
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()
    
def visualizeMetric2(metric='loss'):
    plt.plot(df[metric])
    plt.plot(df['val_' + metric])
    plt.ylabel(metric)
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
#     plt.show()

# %%
# df = pd.read_csv('../training results/training.log')
# df = pd.read_csv('../training results/81%_cnn_lstm_without_images.log')
# df.head(250)

# %%
# df1 = pd.read_csv('../training results/66.9%_20_epoches_dropout_0.2.log')

# df2 = pd.read_csv('../training results/training.log')
# # df2.head(250)

# df = pd.concat([df1, pd.DataFrame(df2)], ignore_index=True)
# df.head(250)

# %%
df = pd.read_csv('../training results/training.log')
df.head(60)
# Out:
#     epoch  accuracy  categorical_crossentropy      loss        lr  precision  \
# 0       0  0.619381                  0.854536  0.854537  0.001000   0.692952
# 1       1  0.667502                  0.774332  0.774332  0.001000   0.724110
# 2       2  0.675603                  0.756124  0.756123  0.001000   0.729684
# 3       3  0.680147                  0.748028  0.748029  0.001000   0.732984
# 4       4  0.679903                  0.746852  0.746852  0.001000   0.732815
# 5       5  0.681038                  0.746463  0.746463  0.001000   0.733920
# 6       6  0.684623                  0.739862  0.739863  0.001000   0.736665
# 7       7  0.685841                  0.734735  0.734736  0.001000   0.738725
# 8       8  0.687529                  0.730154  0.730154  0.001000   0.739747
# 9       9  0.690046                  0.724485  0.724484  0.001000   0.741953
# 10     10  0.691083                  0.722595  0.722597  0.001000   0.742284
# ...

# %%
fig = plt.figure(figsize=(13, 9))

plt.subplot(2, 2, 1)
visualizeMetric2('categorical_crossentropy')
plt.subplot(2, 2, 2)
visualizeMetric2('accuracy')
plt.subplot(2, 2, 3)
visualizeMetric2('recall')
plt.subplot(2, 2, 4)
visualizeMetric2('precision')

plt.show()

# %%
visualizeMetric('loss')

# %% [markdown]
# **Interpretting learning curve**
#
# > https://machinelearningmastery.com/learning-curves-for-diagnosing-machine-learning-model-performance/
